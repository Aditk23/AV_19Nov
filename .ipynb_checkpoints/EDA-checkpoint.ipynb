# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train_updated.csv')
test = pd.read_csv('test_updated.csv')

# %%
train.head()
# Out:
#    Age Gender City Education_Level Is_promoted  Attrition   Salary  \
# 0   28   Male  C23          Master          No          1  57387.0
# 1   43   Male  C13          Master          No          1  65603.0
# 2   29   Male   C9         College          No          1  46368.0
# 3   34   Male   C2         College          No          1  70656.0
# 4   35   Male  C23          Master          No          1  28116.0
#
#    Total Business Value RatingChange
# 0               1715580         Same
# 1                350000         Same
# 2                120360         Same
# 3                     0         Same
# 4               2607180    Decreased

# %%
train.describe(include='all')
# Out:
#                 Age Gender  City Education_Level Is_promoted    Attrition  \
# count   1640.000000   1640  1640            1640        1640  1640.000000
# unique          NaN      2    29               3           2          NaN
# top             NaN   Male   C20          Master          No          NaN
# freq            NaN    964   111             556        1416          NaN
# mean      32.918902    NaN   NaN             NaN         NaN     0.985366
# std        5.930872    NaN   NaN             NaN         NaN     0.120120
# min       21.000000    NaN   NaN             NaN         NaN     0.000000
# 25%       29.000000    NaN   NaN             NaN         NaN     1.000000
# 50%       32.000000    NaN   NaN             NaN         NaN     1.000000
# 75%       37.000000    NaN   NaN             NaN         NaN     1.000000
# max       58.000000    NaN   NaN             NaN         NaN     1.000000
#
#                Salary  Total Business Value RatingChange
# count     1640.000000          1.640000e+03         1640
# unique            NaN                   NaN            3
# top               NaN                   NaN         Same
# freq              NaN                   NaN         1181
# mean     55542.965124          2.203978e+06          NaN
# std      27065.784476          4.705356e+06          NaN
# min      10747.000000         -1.385530e+06          NaN
# 25%      36117.500000          0.000000e+00          NaN
# 50%      51663.500000          4.582250e+05          NaN
# 75%      70169.500000          2.345702e+06          NaN
# max     167758.000000          6.015383e+07          NaN

# %%
pd.set_option('display.max_columns',None)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
train.dtypes
# Out:
# Age                       int64
# Gender                   object
# City                     object
# Education_Level          object
# Is_promoted              object
# Attrition                 int64
# Salary                  float64
# Total Business Value      int64
# RatingChange             object
# dtype: object

# %%
Y=train[['Attrition']]
X=train.drop(['Attrition'],axis=1)

# %%
Y.mean()
# Out:
# Attrition    0.985366
# dtype: float64

# %%
X.RatingChange.value_counts()
# Out:
# Same         1181
# Decreased     376
# Increased      83
# Name: RatingChange, dtype: int64

# %%
X['Gender']= X['Gender'].map({'Male':0 , 'Female':1})
X['Education_Level']= X['Education_Level'].map({'College':0 ,'Bachelor':1, 'Master':2})
X['Is_promoted']= X['Is_promoted'].map({'No':0 , 'Yes':1})
X['RatingChange']= X['RatingChange'].map({'Decreased':-1 , 'Same':0 , 'Increased':1})

# %%
from sklearn import preprocessing

label_encoder = preprocessing.LabelEncoder()
X['City']= label_encoder.fit_transform(X['City'])

# %%
X
# Out:
#       Age  Gender  City  Education_Level  Is_promoted   Salary  \
# 0      28       0    15                2            0  57387.0
# 1      43       0     4                2            0  65603.0
# 2      29       0    28                0            0  46368.0
# 3      34       0    11                0            0  70656.0
# 4      35       0    15                2            0  28116.0
# ...   ...     ...   ...              ...          ...      ...
# 1635   28       0    18                0            0  95133.0
# 1636   26       0    10                1            0  29582.0
# 1637   34       1    28                0            0  12105.0
# 1638   44       0    10                0            0  35370.0
# 1639   28       1    12                2            0  69498.0
#
#       Total Business Value  RatingChange
# 0                  1715580             0
# 1                   350000             0
# 2                   120360             0
# 3                        0             0
# 4                  2607180            -1
# ...                    ...           ...
# 1635                     0             0
# 1636                     0             0
# 1637                     0             0
# 1638               2815090            -1
# 1639                977830            -1
#
# [1640 rows x 8 columns]

# %%
from imblearn.over_sampling import SMOTE

oversample = SMOTE()
X, Y = oversample.fit_resample(X, Y)

# %%
X
# Out:
#       Age  Gender  City  Education_Level  Is_promoted        Salary  \
# 0      28       0    15                2            0  57387.000000
# 1      43       0     4                2            0  65603.000000
# 2      29       0    28                0            0  46368.000000
# 3      34       0    11                0            0  70656.000000
# 4      35       0    15                2            0  28116.000000
# ...   ...     ...   ...              ...          ...           ...
# 3227   36       0     2                0            0  72770.925074
# 3228   33       0    21                0            0  28350.374116
# 3229   36       0     2                0            0  72525.082180
# 3230   37       0     5                0            1  99587.086659
# 3231   27       0     0                0            0  41082.147172
#
#       Total Business Value  RatingChange
# 0                  1715580             0
# 1                   350000             0
# 2                   120360             0
# 3                        0             0
# 4                  2607180            -1
# ...                    ...           ...
# 3227                     0             0
# 3228                215622             0
# 3229                     0             0
# 3230               7802955            -1
# 3231                     0             0
#
# [3232 rows x 8 columns]

# %%
Y.mean()
# Out:
# Attrition    0.5
# dtype: float64

# %%
char = X[['Gender','City','Education_Level','Is_promoted','RatingChange']]

# %%
num=X[['Age','Salary','Total Business Value']]
#char=X.select_dtypes(include="object")

# %%
num
# Out:
#       Age        Salary  Total Business Value
# 0      28  57387.000000               1715580
# 1      43  65603.000000                350000
# 2      29  46368.000000                120360
# 3      34  70656.000000                     0
# 4      35  28116.000000               2607180
# ...   ...           ...                   ...
# 3227   36  72770.925074                     0
# 3228   33  28350.374116                215622
# 3229   36  72525.082180                     0
# 3230   37  99587.086659               7802955
# 3231   27  41082.147172                     0
#
# [3232 rows x 3 columns]

# %%
from sklearn.preprocessing import KBinsDiscretizer
discrete=KBinsDiscretizer(n_bins=10,encode='ordinal', strategy='quantile')
num_binned=pd.DataFrame(discrete.fit_transform(num),index=num.index, columns=num.columns).add_suffix('_Rank')
num_binned.tail()
# Out:
#       Age_Rank  Salary_Rank  Total Business Value_Rank
# 3227       7.0          7.0                        1.0
# 3228       5.0          1.0                        1.0
# 3229       7.0          7.0                        1.0
# 3230       8.0          8.0                        6.0
# 3231       1.0          2.0                        1.0

# %%
from numpy import mean

X_bin_combined=pd.concat([Y,num_binned],axis=1,join='inner')


for col in (num_binned.columns):
    plt.figure()
    sns.lineplot(x=col,y=Y.mean(),data=X_bin_combined,color='red')
    sns.barplot(x=col, y="Attrition",data=X_bin_combined, estimator=mean )
plt.show()

# %%
X_char_merged = pd.concat([Y,char],axis=1,join='inner')


for col in (char.columns):
    plt.figure()
    sns.barplot(x=col, y="Attrition",data=X_char_merged, estimator=mean )
plt.show()

# %%
char
# Out:
#       Gender  City  Education_Level  Is_promoted  RatingChange
# 0          0    15                2            0             0
# 1          0     4                2            0             0
# 2          0    28                0            0             0
# 3          0    11                0            0             0
# 4          0    15                2            0            -1
# ...      ...   ...              ...          ...           ...
# 3227       0     2                0            0             0
# 3228       0    21                0            0             0
# 3229       0     2                0            0             0
# 3230       0     5                0            1            -1
# 3231       0     0                0            0             0
#
# [3232 rows x 5 columns]

# %%
X_all=pd.concat([num_binned,char],axis=1,join="inner")

# %%
X_all
# Out:
#       Age_Rank  Salary_Rank  Total Business Value_Rank  Gender  City  \
# 0          1.0          5.0                        4.0       0    15
# 1          9.0          6.0                        2.0       0     4
# 2          2.0          3.0                        1.0       0    28
# 3          6.0          7.0                        1.0       0    11
# 4          6.0          1.0                        4.0       0    15
# ...        ...          ...                        ...     ...   ...
# 3227       7.0          7.0                        1.0       0     2
# 3228       5.0          1.0                        1.0       0    21
# 3229       7.0          7.0                        1.0       0     2
# 3230       8.0          8.0                        6.0       0     5
# 3231       1.0          2.0                        1.0       0     0
#
#       Education_Level  Is_promoted  RatingChange
# 0                   2            0             0
# 1                   2            0             0
# 2                   0            0             0
# 3                   0            0             0
# 4                   2            0            -1
# ...               ...          ...           ...
# 3227                0            0             0
# 3228                0            0             0
# 3229                0            0             0
# 3230                0            1            -1
# 3231                0            0             0
#
# [3232 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X_all, Y, test_size=0.3, random_state=20)

# %%
print("Shape of Training Data",X_train.shape)
print("Shape of Testing Data",X_test.shape)
print("Attrition Rate in Training Data",y_train.mean())
print("Attrition Rate in Testing Data",y_test.mean())
# Out:
# Shape of Training Data (2262, 8)
# Shape of Testing Data (970, 8)
# Attrition Rate in Training Data Attrition    0.493369
# dtype: float64
# Attrition Rate in Testing Data Attrition    0.515464
# dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier(criterion='gini',random_state=20)

# %%
np.random.seed(44)
from sklearn.model_selection import GridSearchCV
param_dist = {'max_depth': [3, 4, 5], 'min_samples_split': [50,120,180,200,250] }
tree_grid = GridSearchCV(dtree, cv = 10, param_grid=param_dist,n_jobs = 3)
tree_grid.fit(X_train,y_train) 
print('Best Parameters using grid search: \n', tree_grid.best_params_)
# Out:
# Best Parameters using grid search:
#  {'max_depth': 5, 'min_samples_split': 50}

# %%
dtree=DecisionTreeClassifier(criterion='gini',random_state=20,max_depth=5,min_samples_split=50)
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_split=50, random_state=20)

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(criterion='gini',random_state=20,max_depth=4,min_samples_split=50)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=4, min_samples_split=50, random_state=20)

# %%
# Building a Gradient Boosting Model
from sklearn.ensemble import GradientBoostingClassifier
gbm=GradientBoostingClassifier(criterion='mse',random_state=20,max_depth=4,min_samples_split=50)
gbm.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier(criterion='mse', max_depth=4, min_samples_split=50,
#                            random_state=20)

# %%
feature_importances=pd.DataFrame(gbm.feature_importances_,
                                 index=X_train.columns,
                                 columns=['importance']).sort_values('importance',ascending=False)


ax=sns.barplot(x='importance',y=feature_importances.iloc[0:10].index,data=feature_importances.iloc[0:10])

# %%
y_pred_tree=dtree.predict(X_test)
y_pred_rf=rf.predict(X_test)
y_pred_gbm=gbm.predict(X_test)

# %%
from sklearn import metrics

print("f1_score Dtree",metrics.f1_score(y_test,y_pred_tree))
print("f1_score RF",metrics.f1_score(y_test,y_pred_rf))
print("f1_score GB",metrics.f1_score(y_test,y_pred_gbm))
# Out:
# f1_score Dtree 0.8031145717463849
# f1_score RF 0.7804878048780488
# f1_score GB 0.9133192389006343

# %%
test
# Out:
#      Age  Gender City Education_Level Is_promoted    Salary  \
# 0     32  Female  C20          Master         Yes   97722.0
# 1     37    Male  C28         College         Yes   56174.0
# 2     37    Male  C13         College         Yes   96750.0
# 3     39  Female   C8         College         Yes   88813.0
# 4     30    Male   C5          Master         Yes  188418.0
# ..   ...     ...  ...             ...         ...       ...
# 736   38    Male  C29         College         Yes  116006.0
# 737   38    Male  C25         College         Yes  133489.0
# 738   35    Male  C10        Bachelor         Yes   65389.0
# 739   46  Female   C9        Bachelor         Yes  105513.0
# 740   33    Male  C15        Bachelor         Yes  104712.0
#
#      Total Business Value RatingChange
# 0                27458220    Increased
# 1                19866290    Increased
# 2                50382490    Decreased
# 3                17134040    Increased
# 4                58024490    Decreased
# ..                    ...          ...
# 736              59696450    Decreased
# 737              36398090    Increased
# 738              30318780         Same
# 739              28842760    Decreased
# 740              20011620         Same
#
# [741 rows x 8 columns]

# %%
test['Gender']= test['Gender'].map({'Male':0 , 'Female':1})
test['Education_Level']= test['Education_Level'].map({'College':0 ,'Bachelor':1, 'Master':2})
test['Is_promoted']= test['Is_promoted'].map({'No':0 , 'Yes':1})
test['RatingChange']= test['RatingChange'].map({'Decreased':-1 , 'Same':0 , 'Increased':1})

label_encoder = preprocessing.LabelEncoder()
test['City']= label_encoder.fit_transform(test['City'])

# %%
num=test[['Age','Salary','Total Business Value']]

from sklearn.preprocessing import KBinsDiscretizer
discrete=KBinsDiscretizer(n_bins=10,encode='ordinal', strategy='quantile')
num_binned=pd.DataFrame(discrete.fit_transform(num),index=num.index, columns=num.columns).add_suffix('_Rank')
num_binned.tail()
# Out:
#      Age_Rank  Salary_Rank  Total Business Value_Rank
# 736       8.0          9.0                        7.0
# 737       8.0          9.0                        7.0
# 738       6.0          5.0                        7.0
# 739       9.0          8.0                        6.0
# 740       5.0          8.0                        6.0

# %%
# Out:
#      Age  Gender  City  Education_Level  Is_promoted    Salary  \
# 0     32       1    12                2            1   97722.0
# 1     37       0    20                0            1   56174.0
# 2     37       0     4                0            1   96750.0
# 3     39       1    27                0            1   88813.0
# 4     30       0    24                2            1  188418.0
# ..   ...     ...   ...              ...          ...       ...
# 736   38       0    21                0            1  116006.0
# 737   38       0    17                0            1  133489.0
# 738   35       0     1                1            1   65389.0
# 739   46       1    28                1            1  105513.0
# 740   33       0     6                1            1  104712.0
#
#      Total Business Value  RatingChange
# 0                27458220             1
# 1                19866290             1
# 2                50382490            -1
# 3                17134040             1
# 4                58024490            -1
# ..                    ...           ...
# 736              59696450            -1
# 737              36398090             1
# 738              30318780             0
# 739              28842760            -1
# 740              20011620             0
#
# [741 rows x 8 columns]

# %%
test_all=pd.concat([test,num_binned],axis=1,join='inner')
test_all.drop(['Age','Salary','Total Business Value'],axis=1,inplace=True)

# %%
test_all
# Out:
#      Gender  City  Education_Level  Is_promoted  RatingChange  Age_Rank  \
# 0         1    12                2            1             1       4.0
# 1         0    20                0            1             1       7.0
# 2         0     4                0            1            -1       7.0
# 3         1    27                0            1             1       8.0
# 4         0    24                2            1            -1       3.0
# ..      ...   ...              ...          ...           ...       ...
# 736       0    21                0            1            -1       8.0
# 737       0    17                0            1             1       8.0
# 738       0     1                1            1             0       6.0
# 739       1    28                1            1            -1       9.0
# 740       0     6                1            1             0       5.0
#
#      Salary_Rank  Total Business Value_Rank
# 0            8.0                        6.0
# 1            3.0                        6.0
# 2            8.0                        7.0
# 3            7.0                        5.0
# 4            9.0                        7.0
# ..           ...                        ...
# 736          9.0                        7.0
# 737          9.0                        7.0
# 738          5.0                        7.0
# 739          8.0                        6.0
# 740          8.0                        6.0
#
# [741 rows x 8 columns]

# %%
y_pred_test_tree=dtree.predict(test_all)
y_pred_test_rf=rf.predict(test_all)
y_pred_test_gbm=gbm.predict(test_all)

# %%
sub = pd.read_csv('sample_submission.csv')

sub['Target'] = y_pred_test_tree

sub.to_csv('predictions_dt.csv',index=False)

# %%
sub = pd.read_csv('sample_submission.csv')

sub['Target'] = y_pred_test_rf

sub.to_csv('predictions_rf.csv',index=False)

# %%
sub = pd.read_csv('sample_submission.csv')

sub['Target'] = y_pred_test_gbm

sub.to_csv('predictions_gb.csv',index=False)
