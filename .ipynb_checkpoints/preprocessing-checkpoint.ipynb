# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.head(10)
# Out:
#        MMM-YY  Emp_ID  Age Gender City Education_Level  Salary Dateofjoining  \
# 0  2016-01-01       1   28   Male  C23          Master   57387    2015-12-24
# 1  2016-02-01       1   28   Male  C23          Master   57387    2015-12-24
# 2  2016-03-01       1   28   Male  C23          Master   57387    2015-12-24
# 3  2017-11-01       2   31   Male   C7          Master   67016    2017-11-06
# 4  2017-12-01       2   31   Male   C7          Master   67016    2017-11-06
# 5  2016-12-01       4   43   Male  C13          Master   65603    2016-12-07
# 6  2017-01-01       4   43   Male  C13          Master   65603    2016-12-07
# 7  2017-02-01       4   43   Male  C13          Master   65603    2016-12-07
# 8  2017-03-01       4   43   Male  C13          Master   65603    2016-12-07
# 9  2017-04-01       4   43   Male  C13          Master   65603    2016-12-07
#
#   LastWorkingDate  Joining Designation  Designation  Total Business Value  \
# ...

# %%
train.shape
# Out:
# (19104, 13)

# %%
test.head()
# Out:
#    Emp_ID
# 0     394
# 1     173
# 2    1090
# 3     840
# 4     308

# %%
train.dtypes
# Out:
# MMM-YY                  object
# Emp_ID                   int64
# Age                      int64
# Gender                  object
# City                    object
# Education_Level         object
# Salary                   int64
# Dateofjoining           object
# LastWorkingDate         object
# Joining Designation      int64
# Designation              int64
# Total Business Value     int64
# Quarterly Rating         int64
# dtype: object

# %%
train_copy = train.copy()
train_copy=train_copy.groupby('Emp_ID')
train_copy.head()
# Out:
#            MMM-YY  Emp_ID  Age Gender City Education_Level  Salary  \
# 0      2016-01-01       1   28   Male  C23          Master   57387
# 1      2016-02-01       1   28   Male  C23          Master   57387
# 2      2016-03-01       1   28   Male  C23          Master   57387
# 3      2017-11-01       2   31   Male   C7          Master   67016
# 4      2017-12-01       2   31   Male   C7          Master   67016
# ...           ...     ...  ...    ...  ...             ...     ...
# 19097  2017-06-01    2788   29   Male  C27          Master   70254
# 19098  2017-07-01    2788   30   Male  C27          Master   70254
# 19099  2017-08-01    2788   30   Male  C27          Master   70254
# 19100  2017-09-01    2788   30   Male  C27          Master   70254
# 19101  2017-10-01    2788   30   Male  C27          Master   70254
#
#       Dateofjoining LastWorkingDate  Joining Designation  Designation  \
# 0        2015-12-24             NaN                    1            1
# ...

# %%
train.loc[train['Emp_ID']==1]
# Out:
#        MMM-YY  Emp_ID  Age Gender City Education_Level  Salary Dateofjoining  \
# 0  2016-01-01       1   28   Male  C23          Master   57387    2015-12-24
# 1  2016-02-01       1   28   Male  C23          Master   57387    2015-12-24
# 2  2016-03-01       1   28   Male  C23          Master   57387    2015-12-24
#
#   LastWorkingDate  Joining Designation  Designation  Total Business Value  \
# 0             NaN                    1            1               2381060
# 1             NaN                    1            1               -665480
# 2      2016-03-11                    1            1                     0
#
#    Quarterly Rating
# 0                 2
# 1                 2
# 2                 2

# %%
train_copy.first()
# Out:
#             MMM-YY  Age  Gender City Education_Level  Salary Dateofjoining  \
# Emp_ID
# 1       2016-01-01   28    Male  C23          Master   57387    2015-12-24
# 2       2017-11-01   31    Male   C7          Master   67016    2017-11-06
# 4       2016-12-01   43    Male  C13          Master   65603    2016-12-07
# 5       2016-01-01   29    Male   C9         College   46368    2016-01-09
# 6       2017-08-01   31  Female  C11        Bachelor   78728    2017-07-31
# ...            ...  ...     ...  ...             ...     ...           ...
# 2784    2016-01-01   33    Male  C24         College   82815    2012-10-15
# 2785    2017-08-01   34  Female   C9         College   12105    2017-08-28
# 2786    2016-01-01   44    Male  C19         College   35370    2015-07-31
# 2787    2016-01-01   28  Female  C20          Master   69498    2015-07-21
# 2788    2017-06-01   29    Male  C27          Master   70254    2017-06-08
#
#        LastWorkingDate  Joining Designation  Designation  \
# ...

# %%
train_copy.get_group(1)
# Out:
#        MMM-YY  Emp_ID  Age Gender City Education_Level  Salary Dateofjoining  \
# 0  2016-01-01       1   28   Male  C23          Master   57387    2015-12-24
# 1  2016-02-01       1   28   Male  C23          Master   57387    2015-12-24
# 2  2016-03-01       1   28   Male  C23          Master   57387    2015-12-24
#
#   LastWorkingDate  Joining Designation  Designation  Total Business Value  \
# 0             NaN                    1            1               2381060
# 1             NaN                    1            1               -665480
# 2      2016-03-11                    1            1                     0
#
#    Quarterly Rating
# 0                 2
# 1                 2
# 2                 2

# %%
train.groupby('Emp_ID')['Total Business Value'].agg('sum')
# Out:
# Emp_ID
# 1        1715580
# 2              0
# 4         350000
# 5         120360
# 6        1265000
#           ...
# 2784    21748820
# 2785           0
# 2786     2815090
# 2787      977830
# 2788     2298240
# Name: Total Business Value, Length: 2381, dtype: int64
